# %%
import numpy as np
x = np.array([7000,8000,9000,10000,11000])
y = np.array([800000,800000,9000000,1000000,1100000])
mul=x*y
print("multiplication_of_xy",mul)
meanOfXY=np.mean(mul)
print("mean_of_xy",mean)
meanX=np.mean(x)
print("mean_of_x",meanX)
meanY=np.mean(y)
print("mean_Of_Y",meanY)
multiplyofmeanXmeanY=meanX*meanY
print("multiply_of_mean_xy",multiplyofmeanXmeanY)
numerator=meanOfXY-multiplyofmeanXmeanY
print("Numerator",numerator)
xsquare=x*x
print("X_square",xsquare)
meanofxsquare=np.mean(xsquare)
print("mean_of_X_square",meanofxsquare)
wholesquareofmeanx=meanX*meanX
print("whole_square_of_mean_x",wholesquareofmeanx)
denominator=meanofxsquare-wholesquareofmeanx
print("Denomirator",denominator)
# slope
M=numerator/denominator
print("m",M)
# intercept
B=meanY-m*meanX
print("b",B)
# linear regression formula
# Y=mx+b
y=m*12000+B
print("Linear regression",y)
# Out:
# multiplication_of_xy [ 5600000000  6400000000 81000000000 10000000000 12100000000]
# mean_of_xy 23020000000.0
# mean_of_x 9000.0
# mean_Of_Y 2540000.0
# multiply_of_mean_xy 22860000000.0
# Numerator 160000000.0
# X_square [ 49000000  64000000  81000000 100000000 121000000]
# mean_of_X_square 83000000.0
# whole_square_of_mean_x 81000000.0
# Denomirator 2000000.0
# m 80.0
# b 1820000.0
# Linear regression 2780000.0
